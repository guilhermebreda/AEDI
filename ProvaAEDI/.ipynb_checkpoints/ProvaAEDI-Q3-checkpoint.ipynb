# %% [markdown]
# # Bibliotecas

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import numpy as np

import scipy.stats as stats

# %%
# Carregar base de dados
file_path = 'online_retail_II.xlsx'
retail_data = pd.read_excel(file_path)

# Verificar as 5 primeiras linhas
print(retail_data.head())
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %% [markdown]
# ## Análise descritiva

# %%
retail_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525461 entries, 0 to 525460
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      525461 non-null  object
#  1   StockCode    525461 non-null  object
#  2   Description  522533 non-null  object
#  3   Quantity     525461 non-null  int64
#  4   InvoiceDate  525461 non-null  datetime64[ns]
#  5   Price        525461 non-null  float64
#  6   Customer ID  417534 non-null  float64
#  7   Country      525461 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 32.1+ MB

# %%
# Remove missing values
retail_data.dropna(subset=["Quantity", "Price", "Country", "Customer ID"], inplace=True)

# %%
retail_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 417534 entries, 0 to 525460
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      417534 non-null  object
#  1   StockCode    417534 non-null  object
#  2   Description  417534 non-null  object
#  3   Quantity     417534 non-null  int64
#  4   InvoiceDate  417534 non-null  datetime64[ns]
#  5   Price        417534 non-null  float64
#  6   Customer ID  417534 non-null  float64
#  7   Country      417534 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 28.7+ MB

# %%
print(retail_data.describe())
# Out:
#             Quantity                    InvoiceDate          Price  \
# count  525461.000000                         525461  525461.000000
# mean       10.337667  2010-06-28 11:37:36.845017856       4.688834
# min     -9600.000000            2009-12-01 07:45:00  -53594.360000
# 25%         1.000000            2010-03-21 12:20:00       1.250000
# 50%         3.000000            2010-07-06 09:51:00       2.100000
# 75%        10.000000            2010-10-15 12:45:00       4.210000
# max     19152.000000            2010-12-09 20:01:00   25111.090000
# std       107.424110                            NaN     146.126914
#
#          Customer ID
# count  417534.000000
# mean    15360.645478
# min     12346.000000
# 25%     13983.000000
# 50%     15311.000000
# 75%     16799.000000
# max     18287.000000
# std      1680.811316

# %%
# Select relevant columns
selected_cols = ["Quantity", "Price", "Country", "InvoiceDate", "Customer ID", "StockCode", "Description"]
filtered_data = retail_data[selected_cols]

# Filter out negative or zero values
filtered_data = filtered_data[(filtered_data["Quantity"] > 0) & (filtered_data["Price"] > 0)]

# %%
# Criar o pairplot com seaborn
sns.pairplot(filtered_data, diag_kind='kde', palette='Set2')
plt.show()
# Out:
# /Users/guilhermebreda/Development/GitHub/AEDI/.venv/lib/python3.13/site-packages/seaborn/axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /Users/guilhermebreda/Development/GitHub/AEDI/.venv/lib/python3.13/site-packages/seaborn/axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /Users/guilhermebreda/Development/GitHub/AEDI/.venv/lib/python3.13/site-packages/seaborn/axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /Users/guilhermebreda/Development/GitHub/AEDI/.venv/lib/python3.13/site-packages/seaborn/axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# /Users/guilhermebreda/Development/GitHub/AEDI/.venv/lib/python3.13/site-packages/seaborn/axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# /Users/guilhermebreda/Development/GitHub/AEDI/.venv/lib/python3.13/site-packages/seaborn/axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# /Users/guilhermebreda/Development/GitHub/AEDI/.venv/lib/python3.13/site-packages/seaborn/axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# /Users/guilhermebreda/Development/GitHub/AEDI/.venv/lib/python3.13/site-packages/seaborn/axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# /Users/guilhermebreda/Development/GitHub/AEDI/.venv/lib/python3.13/site-packages/seaborn/axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)

# %%
## 2. Histograms - Distribution of Quantity and Price
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.histplot(filtered_data["Quantity"], bins=50, kde=True, color='blue')
plt.title("Distribution of Quantity")

plt.subplot(1, 2, 2)
sns.histplot(filtered_data["Price"], bins=50, kde=True, color='green')
plt.title("Distribution of Price")
plt.show()

# %%
## 3. Boxplots - Detecting Outliers
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.boxplot(x=filtered_data["Quantity"], color='blue')
plt.title("Boxplot of Quantity")

plt.subplot(1, 2, 2)
sns.boxplot(x=filtered_data["Price"], color='green')
plt.title("Boxplot of Price")
plt.show()

# %%
## 4. Top 10 Countries by Total Sales Volume
top_countries = filtered_data.groupby("Country")["Quantity"].sum().sort_values(ascending=False).head(10)
plt.figure(figsize=(10, 5))
sns.barplot(x=top_countries.values, y=top_countries.index, palette="Blues_r")
plt.xlabel("Total Quantity Sold")
plt.ylabel("Country")
plt.title("Top 10 Countries by Total Sales Volume")
plt.show()
# Out:
# /var/folders/vw/w4z357v90f599jyt6ljmc29w0000gn/T/ipykernel_19472/3090987890.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_countries.values, y=top_countries.index, palette="Blues_r")

# %%
## 5. Correlation Analysis - Heatmap
corr_matrix = filtered_data[["Quantity", "Price"]].corr()
plt.figure(figsize=(8, 5))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
## 6. Monthly Sales Trends
filtered_data["Month"] = filtered_data["InvoiceDate"].dt.to_period("M")
monthly_sales = filtered_data.groupby("Month")["Quantity"].sum()

plt.figure(figsize=(12, 5))
sns.lineplot(x=monthly_sales.index.astype(str), y=monthly_sales.values, marker="o", color="red")
plt.xticks(rotation=45)
plt.title("Monthly Sales Trends")
plt.xlabel("Month")
plt.ylabel("Total Quantity Sold")
plt.show()

# %%
## 7. Most Sold Products
top_products = filtered_data.groupby("Description")["Quantity"].sum().sort_values(ascending=False).head(10)
plt.figure(figsize=(10, 5))
sns.barplot(x=top_products.values, y=top_products.index, palette="Greens_r")
plt.xlabel("Total Quantity Sold")
plt.ylabel("Product")
plt.title("Top 10 Most Sold Products")
plt.show()
# Out:
# /var/folders/vw/w4z357v90f599jyt6ljmc29w0000gn/T/ipykernel_19472/3378816143.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_products.values, y=top_products.index, palette="Greens_r")

# %%
## 8. Customer Insights - Unique Customers and Average Purchase Quantity
unique_customers = filtered_data["Customer ID"].nunique()
avg_purchase_per_customer = filtered_data.groupby("Customer ID")["Quantity"].sum().mean()

print(f"Total Unique Customers: {unique_customers}")
print(f"Average Purchase Quantity per Customer: {avg_purchase_per_customer:.2f}")
# Out:
# Total Unique Customers: 4312
# Average Purchase Quantity per Customer: 1284.40

# %%
## 9. Invoice Analysis - Transactions Over Time
daily_transactions = filtered_data.groupby(filtered_data["InvoiceDate"].dt.date)["InvoiceDate"].count()

plt.figure(figsize=(12, 5))
sns.lineplot(x=daily_transactions.index, y=daily_transactions.values, color="purple")
plt.xticks(rotation=45)
plt.title("Number of Transactions Over Time")
plt.xlabel("Date")
plt.ylabel("Number of Transactions")
plt.show()

# %% [markdown]
# ## Filtrar colunas relevantes p/ ANOVA

# %%
# Selecionar as colunas relevantes, incluindo "Country" para ANOVA
selected_cols = ["Quantity", "Price", "Country"]
filtered_data = retail_data[selected_cols]

# %%
# Filtrar valores inconsistentes (excluir quantidades e preços negativos ou zero)
filtered_data = filtered_data[(filtered_data["Quantity"] > 0) & (filtered_data["Price"] > 0)]

# %% [markdown]
# ## ANOVA

# %%
# 1. Remove missing values and filter relevant columns
anova_data = filtered_data[['Country', 'Quantity', 'Price']].dropna()

# 2. Perform ANOVA for Quantity
quantity_groups = [group["Quantity"].values for _, group in anova_data.groupby("Country")]
f_stat_quantity, p_value_quantity = stats.f_oneway(*quantity_groups)

# 3. Perform ANOVA for Price
price_groups = [group["Price"].values for _, group in anova_data.groupby("Country")]
f_stat_price, p_value_price = stats.f_oneway(*price_groups)

# 4. Display Results
print("\n🔹 **ANOVA for Quantity Sold**")
print(f"F-Statistic: {f_stat_quantity:.2f}, P-Value: {p_value_quantity:.4f}")

print("\n🔹 **ANOVA for Product Price**")
print(f"F-Statistic: {f_stat_price:.2f}, P-Value: {p_value_price:.4f}")

# 5. Interpretation
if p_value_quantity < 0.05:
    print("\n✅ Quantity differences between countries are statistically significant!")
else:
    print("\n❌ No significant differences found in quantity sold among countries.")

if p_value_price < 0.05:
    print("\n✅ Price differences between countries are statistically significant!")
else:
    print("\n❌ No significant differences found in product prices among countries.")
# Out:
# 🔹 **ANOVA for Quantity Sold**
# F-Statistic: 408.84, P-Value: 0.0000
#
# 🔹 **ANOVA for Product Price**
# F-Statistic: 14.80, P-Value: 0.0000
#
# ✅ Quantity differences between countries are statistically significant!
#
# ✅ Price differences between countries are statistically significant!

# %% [markdown]
# ### Teste Shapiro-Wilk e Levene

# %%
import scipy.stats as stats

# 1. Check Normality of Residuals using Shapiro-Wilk Test
anova_data["Quantity_Residuals"] = anova_data["Quantity"] - anova_data.groupby("Country")["Quantity"].transform("mean")
anova_data["Price_Residuals"] = anova_data["Price"] - anova_data.groupby("Country")["Price"].transform("mean")

shapiro_quantity = stats.shapiro(anova_data["Quantity_Residuals"])
shapiro_price = stats.shapiro(anova_data["Price_Residuals"])

print("\n🔹 **Shapiro-Wilk Test for Normality**")
print(f"Quantity Residuals - W: {shapiro_quantity[0]:.4f}, P-Value: {shapiro_quantity[1]:.4f}")
print(f"Price Residuals - W: {shapiro_price[0]:.4f}, P-Value: {shapiro_price[1]:.4f}")

# 2. Check Homogeneity of Variances using Levene’s Test
levene_quantity = stats.levene(*quantity_groups)
levene_price = stats.levene(*price_groups)

print("\n🔹 **Levene’s Test for Homogeneity of Variances**")
print(f"Quantity - W: {levene_quantity[0]:.2f}, P-Value: {levene_quantity[1]:.4f}")
print(f"Price - W: {levene_price[0]:.2f}, P-Value: {levene_price[1]:.4f}")

# ✅ 3. Interpretation
if shapiro_quantity[1] < 0.05:
    print("\n❌ Quantity residuals are NOT normally distributed!")
else:
    print("\n✅ Quantity residuals follow a normal distribution.")

if shapiro_price[1] < 0.05:
    print("❌ Price residuals are NOT normally distributed!")
else:
    print("✅ Price residuals follow a normal distribution.")

if levene_quantity[1] < 0.05:
    print("\n❌ Variance in quantity is NOT homogeneous across countries!")
else:
    print("\n✅ Variance in quantity is homogeneous across countries.")

if levene_price[1] < 0.05:
    print("❌ Variance in price is NOT homogeneous across countries!")
else:
    print("✅ Variance in price is homogeneous across countries.")
# Out:
# 🔹 **Shapiro-Wilk Test for Normality**
# Quantity Residuals - W: 0.0661, P-Value: 0.0000
# Price Residuals - W: 0.0134, P-Value: 0.0000
#
# 🔹 **Levene’s Test for Homogeneity of Variances**
# Quantity - W: 390.28, P-Value: 0.0000
# Price - W: 15.01, P-Value: 0.0000
#
# ❌ Quantity residuals are NOT normally distributed!
# ❌ Price residuals are NOT normally distributed!
#
# ❌ Variance in quantity is NOT homogeneous across countries!
# ❌ Variance in price is NOT homogeneous across countries!
# /Users/guilhermebreda/Development/GitHub/AEDI/.venv/lib/python3.13/site-packages/scipy/stats/_axis_nan_policy.py:573: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 407664.
#   res = hypotest_fun_out(*samples, **kwds)

# %% [markdown]
# ### Alternativa a ANOVA

# %%
# 1. Kruskal-Wallis Test (for non-normal data)
kw_quantity = stats.kruskal(*quantity_groups)
kw_price = stats.kruskal(*price_groups)

print("\n🔹 **Kruskal-Wallis Test for Non-Normal Data**")
print(f"Quantity - H: {kw_quantity[0]:.2f}, P-Value: {kw_quantity[1]:.4f}")
print(f"Price - H: {kw_price[0]:.2f}, P-Value: {kw_price[1]:.4f}")

# 2. Welch’s ANOVA (for unequal variances)
welch_quantity = stats.ttest_ind(*quantity_groups, equal_var=False)
welch_price = stats.ttest_ind(*price_groups, equal_var=False)

print("\n🔹 **Welch’s ANOVA for Unequal Variances**")
print(f"Quantity - T: {welch_quantity[0]:.2f}, P-Value: {welch_quantity[1]:.4f}")
print(f"Price - T: {welch_price[0]:.2f}, P-Value: {welch_price[1]:.4f}")
# Out:
# 🔹 **Kruskal-Wallis Test for Non-Normal Data**
# Quantity - H: 14977.50, P-Value: 0.0000
# Price - H: 924.60, P-Value: 0.0000
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 10
#       7 print(f"Price - H: {kw_price[0]:.2f}, P-Value: {kw_price[1]:.4f}")
#       9 # 2. Welch’s ANOVA (for unequal variances)
# ---> 10 welch_quantity = stats.ttest_ind(*quantity_groups, equal_var=False)
#      11 welch_price = stats.ttest_ind(*price_groups, equal_var=False)
#      13 print("\n🔹 **Welch’s ANOVA for Unequal Variances**")
#
# File ~/Development/GitHub/AEDI/.venv/lib/python3.13/site-packages/scipy/stats/_axis_nan_policy.py:456, in _axis_nan_policy_factory.<locals>.axis_nan_policy_decorator.<locals>.axis_nan_policy_wrapper(_no_deco, *args, **kwds)
#     453 maxarg = (np.inf if inspect.getfullargspec(hypotest_fun_in).varargs
#     454           else len(inspect.getfullargspec(hypotest_fun_in).args))
#     455 if len(args) > maxarg:  # let the function raise the right error
# --> 456     hypotest_fun_in(*args, **kwds)
#     458 # raise if multiple values passed for same parameter
#     459 d_args = dict(zip(params, args))
#
# TypeError: ttest_ind() got multiple values for argument 'equal_var'
